# %%
import numpy as np

np.random.seed(42)
x = np.random.uniform(0, 2 * np.pi, 1000)
x_1 = x ** 3
x_2 = np.sin(x)
noise = np.random.normal(1, 0.2, 1000)
y = 2 - x_1 + 3 * x_2 + noise

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_3 = (x ** 2).reshape(-1,1)
X = np.column_stack((x, x_1, x_2, x_3))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

ln = LinearRegression(fit_intercept=False)
ln.fit(X_train[:,3].reshape(-1,1), y_train)
y_pred_train = ln.predict(X_train[:,3].reshape(-1,1)) + 2
y_pred_test = ln.predict(X_test[:,3].reshape(-1,1)) + 2

plt.scatter(X_train[:,0], y_train, s=8, label="True train data")
plt.scatter(X_train[:,0], y_pred_train, s=8, label="Predicted train data")
plt.scatter(X_test[:,0], y_test, s=8, label="True test data")
plt.scatter(X_test[:,0], y_pred_test, s=8, label="Predicted test data")
plt.legend()
plt.show()
ln.intercept_ , ln.coef_
# Out:
# (0.0, array([-5.17264297]))

# %%
from sklearn.metrics import mean_squared_error

mse_train = mean_squared_error(y_train, y_pred_train)
mse_test = mean_squared_error(y_test, y_pred_test)

rmse_train = np.sqrt(mse_train)
rmse_test = np.sqrt(mse_test)

ndei_train = rmse_train / np.std(y_train)
ndei_test = rmse_test / np.std(y_test)

print(f"mse_train : {mse_train}")
print(f"mse_test : {mse_test}")
print(f"rmse_train : {rmse_train}")
print(f"rmse_test : {rmse_test}")
print(f"ndei_train : {ndei_train}")
print(f"ndei_test : {ndei_test}")
# Out:
# mse_train : 119.4790052670936
# mse_test : 117.90094323040304
# rmse_train : 10.930645235625095
# rmse_test : 10.858220076532021
# ndei_train : 0.15163495140989064
# ndei_test : 0.15336169202713498

# %%
ln.fit(X_train[:,[1,2]], y_train)
y_pred_train = ln.predict(X_train[:,[1,2]])
y_pred_test = ln.predict(X_test[:,[1,2]])

plt.scatter(X_train[:,0], y_train, s=8, label="True train data")
plt.scatter(X_train[:,0], y_pred_train, s=8, label="Predicted train data")
plt.scatter(X_test[:,0], y_test, s=8, label="True test data")
plt.scatter(X_test[:,0], y_pred_test, s=8, label="Predicted test data")
plt.legend()
plt.show()

mse_train = mean_squared_error(y_train, y_pred_train)
mse_test = mean_squared_error(y_test, y_pred_test)

rmse_train = np.sqrt(mse_train)
rmse_test = np.sqrt(mse_test)

ndei_train = rmse_train / np.std(y_train)
ndei_test = rmse_test / np.std(y_test)

print(f"mse_train : {mse_train}")
print(f"mse_test : {mse_test}")
print(f"rmse_train : {rmse_train}")
print(f"rmse_test : {rmse_test}")
print(f"ndei_train : {ndei_train}")
print(f"ndei_test : {ndei_test}")
# Out:
# mse_train : 0.04034136499197905
# mse_test : 0.03558283775818162
# rmse_train : 0.20085159942599176
# rmse_test : 0.18863413730865794
# ndei_train : 0.00278630601058176
# ndei_test : 0.002664271885063351
